# %%
import sys
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)
# Out:
# Python version
# 3.9.0 (default, Dec  2 2020, 10:36:36)
# [Clang 12.0.0 (clang-1200.0.32.27)]
# Version info.
# sys.version_info(major=3, minor=9, micro=0, releaselevel='final', serial=0)

# %%
import os
os.sys.path
# Out:
# ['/Users/lilith/Projekte/cdp_tests/pytests',
#  '',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/Cellar/jupyterlab/2.2.9_1/libexec/lib/python3.9/site-packages',
#  '/Users/lilith/Projekte/cdp_tests/pytests',
#  '/usr/local/Cellar/python@3.9/3.9.0_4/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/usr/local/Cellar/python@3.9/3.9.0_4/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/usr/local/Cellar/python@3.9/3.9.0_4/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/lib/python3.9/site-packages/geos',
#  '/usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages',
#  '/usr/local/lib/python3.9/site-packages/IPython/extensions',
#  '/Users/lilith/.ipython']

# %%
sys.path.append('/usr/local/lib/python3.9/site-packages')
import cv2

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]
    
def cannyUpdate(x):
    edges = cv.Canny(img,x,200)
    
    plt.subplot(121)
    plt.imshow(img,cmap = 'gray')
    plt.title('Original Image')
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(122)
    plt.imshow(edges,cmap = 'gray')
    plt.title('Edge Image')
    plt.xticks([])
    plt.yticks([])
    
    plt.show()
    return x

img = cv.imread('../data/1607447302.png',0)

interact(cannyUpdate, x=(0, 250, 1));
# Out:
# interactive(children=(IntSlider(value=125, description='x', max=250), Output()), _dom_classes=('widget-interac…
